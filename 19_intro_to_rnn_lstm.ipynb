# %% [markdown]
# # Introduction to Recurrent Neural Networks
#
#  ![](https://i2.wp.com/www.codeastar.com/wp-content/uploads/2019/05/30chvx-e1557285255637.jpg?w=1200&ssl=1) ![](https://pics.me.me/input-audio-1-recurrent-neural-network-sparse-shape-mouth-texture2-32955013.png) ![](https://miro.medium.com/max/627/1*go8PHsPNbbV6qRiwpUQ5BQ.png)
#
# ## Prerequisites
#
# * Convolutional Neural Networks
#
# * Time Series
#
# ## Learning Goals
#
# * Be able to explain why FFNNs are not suitable for dealing with Time Series (sequential) data structures.
#
# * Be able to explain why we add an attention mechanism to a Recurrent Neural Network (effectively creating an LSTM or GRU-like model):
#     * The problem of vanishing gradients.
#
# ![](https://i.pinimg.com/originals/4e/82/f6/4e82f615d99b142073a1a53664e101f6.png)
#
# * Be able to use a pre-trained model for Text Classification and Text Generation.
#
# -----
#
# ## Le Meme
#
# ![](https://pics.me.me/linear-svm-multi-layer-feedforward-neural-network-long-short-term-memory-recurrent-29180470.png)
#
# -----
#
# # References / Resources
#
# ## Introductory References
#
# * [The Unreasonable Effectiveness of RNNs](http://karpathy.github.io/2015/05/21/rnn-effectiveness/)
#
# * [Understanding LSTMs](https://colah.github.io/posts/2015-08-Understanding-LSTMs/)
#
# ## Sesame Street Models
#
# * [BERT and ELMo](http://jalammar.github.io/illustrated-bert/)
#
# ## Text Generation
#
# * [Character-RNN for Text Generation](https://github.com/minimaxir/textgenrnn)
#
# ## Text Classification
#
# * [Spam Classifier w/ Transfer Learning](https://heartbeat.fritz.ai/using-transfer-learning-and-pre-trained-language-models-to-classify-spam-549fc0f56c20)
#
# * [Quora Insincere Question Classifier w/ Bi-LSTM in PyTorch](https://www.kaggle.com/mihaskalic/dynamic-lstm-pytorch-starter)
#
# * [What is a Bi-LSTM?](https://datascience.stackexchange.com/questions/25650/what-is-lstm-bilstm-and-when-to-use-them)
#
# ## The Future?
#
# * [Why TCNs are Better than RNNs](https://towardsdatascience.com/the-fall-of-rnn-lstm-2d1594c74ce0)
#
# * [Keras-TCN Implementation](https://github.com/philipperemy/keras-tcn)
#
# ## Forecasting the Stock Market
#
# * [A Feature-Fusion LSTM-CNN Hybrid Model](https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0212320&type=printable)
#
# * [RNN, LSTM, LSTM-Peephole, GRU Models](https://www.kaggle.com/raoulma/ny-stock-price-prediction-rnn-lstm-gru#4.-Model-and-validate-data-)
#
# ## Inexpensive TPU Solutions
#
# * [Coral USB TPU Coprocessor](https://coral.ai/products/accelerator/)
#
# * [Converting from TF to TF-Lite](https://www.tensorflow.org/lite/convert)
#
# * [Deep Learning Model Convertors](https://github.com/ysh329/deep-learning-model-convertor)
#
# * [Converting from PyTorch to Tensorflow](https://towardsdatascience.com/converting-a-simple-deep-learning-model-from-pytorch-to-tensorflow-b6b353351f5d)
